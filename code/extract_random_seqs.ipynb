# %%
from Bio import SeqIO
from Bio import Seq
import pandas as pd
import numpy as np
import random
import csv
import re
import os

# %%
def seqToString(motif):
    """
    motif: a Seq that represents the motif 
    
    Returns the String representation of the motif
    """
    i = 0
    string = ""
    length = motif.__len__()
    while i < length:
        string += motif.__getitem__(i)
        i += 1
    return string

# %%
def getNegative(pos_seq):
    """
    pos_seq = dna sequence in the positive direction reading from the file
    
    Returns the negative counterpart of the positive sequence.
    """
    dict = {"A":'T','T':'A','G':'C','C':'G','-':'-','N':'N'}
    negative = ""
    last_index = len(pos_seq) - 1
    while last_index > -1:
        negative += dict[pos_seq[last_index].upper()]
        last_index -= 1
    return negative

# %%
def randomize_strand(length):
    strands = []
    for i in np.arange(length):
        r = random.random()
        if r < 0.5:
            strands += ["positive"]
        else:
            strands += ["negative"]
    return strands

# %%
def randomize_position(spec, no_thresh_path, length, path_to_raw):
    #1. get non thresholded file and group by species.max()
    no_thresh = pd.read_csv(no_thresh_path) 
    subsetted = no_thresh.groupby('species').max()
    max_align_positions = subsetted["align_position"].values
    rand_pos = []
    #2. iterate through max values and randomly generate an index in the middle
    for i in np.arange(len(max_align_positions)):
        random_index = random.randint(0, max_align_positions[i])
        rand_pos += [random_index]
    print(rand_pos)
    #3. drop uneeded columns in "thresholded file"
    subsetted = subsetted.drop(columns = ['score', 'motif', 'raw_position', 'Unnamed: 0'])
    subsetted['align_position'] = np.array(rand_pos)
    subsetted['strand'] = np.array(randomize_strand(len(rand_pos)))
    no_thresh = no_thresh.drop(columns = ['motif', 'Unnamed: 0', 'score']) 
    #4.add randomly generated column as the raw_positions column for my "thresholded" file
    result = pd.merge(subsetted, no_thresh, on = ['align_position', 'strand'])
    return(result)

# %%
randomize_position("VT6436", "~/motif_extraction/data/sub_no_map_motif_bcd_no_threshold/VT6436.fa.csv", 5, "VT6436.fa")
# Out:
# [1308, 1430, 3185, 2166, 1824, 1243, 3590, 2612, 826, 136, 997, 2052, 1660, 624, 3110, 956, 2792, 542, 267, 998, 279, 1454, 3635, 1994]
#        strand  align_position                   species  raw_position
# 0    negative            1308  VT6436|1|MEMB004E|-|2496           979
# 1    negative            1308  VT6436|1|MEMB006C|-|2759          1051
# 2    positive            1430  VT6436|1|MEMB005D|+|2691          1085
# 3    positive            3185  VT6436|1|MEMB002A|+|2701          2106
# 4    positive            3185  VT6436|1|MEMB002B|-|2408          1877
# 5    positive            3185  VT6436|1|MEMB002C|+|2709          2128
# 6    positive            3185  VT6436|1|MEMB002D|-|2501          1945
# 7    positive            3185  VT6436|1|MEMB002E|-|2699          2120
# 8    positive            3185  VT6436|1|MEMB002F|-|2670          2129
# 9    positive            3185  VT6436|1|MEMB003A|-|2262          1807
# 10   positive            3185  VT6436|1|MEMB003B|+|2585          2024
# 11   positive            3185  VT6436|1|MEMB003C|-|2741          2138
# 12   positive            3185  VT6436|1|MEMB003D|-|2312          1790
# 13   positive            3185  VT6436|1|MEMB003F|-|2611          2077
# 14   positive            3185  VT6436|1|MEMB004A|+|2422          1886
# 15   positive            3185  VT6436|1|MEMB004B|+|2551          2022
# 16   positive            3185  VT6436|1|MEMB004E|-|2496          1956
# 17   positive            3185  VT6436|1|MEMB005B|-|2784          2232
# 18   positive            3185  VT6436|1|MEMB005D|+|2691          2151
# 19   positive            3185  VT6436|1|MEMB006A|+|2653          2113
# 20   positive            3185  VT6436|1|MEMB006B|-|2624          2059
# 21   positive            3185  VT6436|1|MEMB006C|-|2759          2167
# 22   positive            3185  VT6436|1|MEMB007B|-|2711          2122
# 23   positive            3185  VT6436|1|MEMB007C|-|2597          2050
# 24   positive            3185  VT6436|1|MEMB007D|-|2947          2389
# 25   positive            3185  VT6436|1|MEMB008C|+|2558          2014
# 26   positive            3185      VT6436|1|dkik|+|2321          1797
# 27   positive            2166  VT6436|1|MEMB002A|+|2701          1552
# 28   positive            2166  VT6436|1|MEMB002B|-|2408          1464
# 29   positive            2166  VT6436|1|MEMB002C|+|2709          1574
# ..        ...             ...                       ...           ...
# 343  negative            3635  VT6436|1|MEMB006C|-|2759          2563
# 344  negative            3635  VT6436|1|MEMB007B|-|2711          2493
# 345  negative            3635  VT6436|1|MEMB007C|-|2597          2382
# 346  negative            3635  VT6436|1|MEMB007D|-|2947          2736
# 347  negative            3635  VT6436|1|MEMB008C|+|2558          2349
# 348  negative            3635      VT6436|1|dkik|+|2321          2120
# 349  positive            1994  VT6436|1|MEMB002A|+|2701          1417
# 350  positive            1994  VT6436|1|MEMB002B|-|2408          1370
# 351  positive            1994  VT6436|1|MEMB002C|+|2709          1439
# 352  positive            1994  VT6436|1|MEMB002D|-|2501          1324
# 353  positive            1994  VT6436|1|MEMB002E|-|2699          1313
# 354  positive            1994  VT6436|1|MEMB002F|-|2670          1474
# 355  positive            1994  VT6436|1|MEMB003A|-|2262          1310
# 356  positive            1994  VT6436|1|MEMB003B|+|2585          1443
# 357  positive            1994  VT6436|1|MEMB003C|-|2741          1459
# 358  positive            1994  VT6436|1|MEMB003D|-|2312          1279
# 359  positive            1994  VT6436|1|MEMB003F|-|2611          1439
# 360  positive            1994  VT6436|1|MEMB004A|+|2422          1377
# 361  positive            1994  VT6436|1|MEMB004B|+|2551          1392
# 362  positive            1994  VT6436|1|MEMB004E|-|2496          1462
# 363  positive            1994  VT6436|1|MEMB005B|-|2784          1438
# 364  positive            1994  VT6436|1|MEMB005D|+|2691          1575
# 365  positive            1994  VT6436|1|MEMB006A|+|2653          1544
# 366  positive            1994  VT6436|1|MEMB006B|-|2624          1473
# 367  positive            1994  VT6436|1|MEMB006C|-|2759          1526
# 368  positive            1994  VT6436|1|MEMB007B|-|2711          1441
# 369  positive            1994  VT6436|1|MEMB007C|-|2597          1480
# 370  positive            1994  VT6436|1|MEMB007D|-|2947          1557
# 371  positive            1994  VT6436|1|MEMB008C|+|2558          1429
# 372  positive            1994      VT6436|1|dkik|+|2321          1292
#
# [373 rows x 4 columns]

# %%
def raw_string(spec, length, no_thresh_path, motif_key, path_to_raw):
    """ spec: The region number ex: 11048
        length: The length of the sequence that we want
        path: The path to the folder with the thresholded and non thresholded directories
        
        Returns a csv saved under data/output/full_raw_motif_extraction/*spec*
        """
    
    result = randomize_position(spec, no_thresh_path, length, path_to_raw)
    print(result)
    num_spec = spec.split('.')[0]
    if num_spec[0] == "_":
        num_spec = num_spec[1:]
    spec_path = path_to_raw + "/outlier_rm_with_length_"+str(num_spec)+".fa"
    record_dict = SeqIO.to_dict(SeqIO.parse(spec_path, "fasta"))
    
    sequences = []
    
    for index, row in result.iterrows():
        speci = row['species']
        pos = row['raw_position']
        strand = row['strand']
        seq = record_dict[speci]
        if strand == 'negative':
            sequences.append(getNegative(seqToString(seq[pos:pos + length])))
        else:
            sequences.append(seqToString(seq[pos:pos + length]))
    result['raw_seq'] = np.array(sequences)
    print(result)
    path = os.path.join("/Users/niharikadesaraju/motif_extraction/data/output", str(num_spec) + "_random.csv")
    print(path)
    result.to_csv(path)

# %%
raw_string("VT6436", 5, "/Users/niharikadesaraju/motif_extraction/data/sub_no_map_motif_bcd_no_threshold/VT6436.fa.csv", "VT6436.fa", "/Users/niharikadesaraju/motif_extraction/data/raw")
# Out:
# [1606, 2188, 1825, 1374, 2488, 1875, 3876, 47, 1656, 3362, 691, 109, 2480, 2061, 103, 2882, 2295, 6, 2964, 1448, 1574, 2892, 637, 1019]
#        strand  align_position                   species  raw_position
# 0    positive            1606  VT6436|1|MEMB002A|+|2701          1093
# 1    positive            1606  VT6436|1|MEMB002B|-|2408          1091
# 2    positive            1606  VT6436|1|MEMB002C|+|2709          1115
# 3    positive            1606  VT6436|1|MEMB002D|-|2501          1020
# 4    positive            1606  VT6436|1|MEMB002E|-|2699          1014
# 5    positive            1606  VT6436|1|MEMB002F|-|2670          1171
# 6    positive            1606  VT6436|1|MEMB003A|-|2262          1017
# 7    positive            1606  VT6436|1|MEMB003B|+|2585          1130
# 8    positive            1606  VT6436|1|MEMB003C|-|2741          1135
# 9    positive            1606  VT6436|1|MEMB003D|-|2312           986
# 10   positive            1606  VT6436|1|MEMB003F|-|2611          1128
# 11   positive            1606  VT6436|1|MEMB004A|+|2422          1104
# 12   positive            1606  VT6436|1|MEMB004B|+|2551          1094
# 13   positive            1606  VT6436|1|MEMB004E|-|2496          1173
# 14   positive            1606  VT6436|1|MEMB005B|-|2784          1139
# 15   positive            1606  VT6436|1|MEMB005D|+|2691          1241
# 16   positive            1606  VT6436|1|MEMB006A|+|2653          1206
# 17   positive            1606  VT6436|1|MEMB006B|-|2624          1158
# 18   positive            1606  VT6436|1|MEMB006C|-|2759          1246
# 19   positive            1606  VT6436|1|MEMB007B|-|2711          1142
# 20   positive            1606  VT6436|1|MEMB007C|-|2597          1162
# 21   positive            1606  VT6436|1|MEMB007D|-|2947          1227
# 22   positive            1606  VT6436|1|MEMB008C|+|2558          1130
# 23   positive            1606      VT6436|1|dkik|+|2321           997
# 24   positive            2188  VT6436|1|MEMB002A|+|2701          1573
# 25   positive            2188  VT6436|1|MEMB002B|-|2408          1486
# 26   positive            2188  VT6436|1|MEMB002C|+|2709          1595
# 27   positive            2188  VT6436|1|MEMB002D|-|2501          1457
# 28   positive            2188  VT6436|1|MEMB002E|-|2699          1447
# 29   positive            2188  VT6436|1|MEMB002F|-|2670          1640
# ..        ...             ...                       ...           ...
# 387  positive            1574  VT6436|1|MEMB006B|-|2624          1131
# 388  positive            1574  VT6436|1|MEMB006C|-|2759          1215
# 389  positive            1574  VT6436|1|MEMB007B|-|2711          1115
# 390  positive            1574  VT6436|1|MEMB007C|-|2597          1135
# 391  positive            1574  VT6436|1|MEMB007D|-|2947          1199
# 392  positive            1574  VT6436|1|MEMB008C|+|2558          1103
# 393  positive            1574      VT6436|1|dkik|+|2321           970
# 394  negative            2892  VT6436|1|MEMB007D|-|2947          2123
# 395  negative             637  VT6436|1|MEMB003C|-|2741           519
# 396  negative            1019  VT6436|1|MEMB002A|+|2701           830
# 397  negative            1019  VT6436|1|MEMB002B|-|2408           785
# 398  negative            1019  VT6436|1|MEMB002C|+|2709           828
# 399  negative            1019  VT6436|1|MEMB002F|-|2670           845
# 400  negative            1019  VT6436|1|MEMB003A|-|2262           789
# 401  negative            1019  VT6436|1|MEMB003B|+|2585           840
# 402  negative            1019  VT6436|1|MEMB003C|-|2741           838
# 403  negative            1019  VT6436|1|MEMB003D|-|2312           769
# 404  negative            1019  VT6436|1|MEMB003F|-|2611           862
# 405  negative            1019  VT6436|1|MEMB004A|+|2422           779
# 406  negative            1019  VT6436|1|MEMB004B|+|2551           813
# 407  negative            1019  VT6436|1|MEMB004E|-|2496           843
# 408  negative            1019  VT6436|1|MEMB005B|-|2784           845
# 409  negative            1019  VT6436|1|MEMB005D|+|2691           857
# 410  negative            1019  VT6436|1|MEMB006B|-|2624           865
# 411  negative            1019  VT6436|1|MEMB006C|-|2759           838
# 412  negative            1019  VT6436|1|MEMB007B|-|2711           849
# 413  negative            1019  VT6436|1|MEMB007C|-|2597           853
# 414  negative            1019  VT6436|1|MEMB007D|-|2947           873
# 415  negative            1019  VT6436|1|MEMB008C|+|2558           826
# 416  negative            1019      VT6436|1|dkik|+|2321           774
#
# [417 rows x 4 columns]
#        strand  align_position                   species  raw_position raw_seq
# 0    positive            1606  VT6436|1|MEMB002A|+|2701          1093   TCGCG
# 1    positive            1606  VT6436|1|MEMB002B|-|2408          1091   TCAAG
# 2    positive            1606  VT6436|1|MEMB002C|+|2709          1115   TCGCG
# 3    positive            1606  VT6436|1|MEMB002D|-|2501          1020   TCTAG
# 4    positive            1606  VT6436|1|MEMB002E|-|2699          1014   TCTAA
# 5    positive            1606  VT6436|1|MEMB002F|-|2670          1171   TCAAG
# 6    positive            1606  VT6436|1|MEMB003A|-|2262          1017   TCTAG
# 7    positive            1606  VT6436|1|MEMB003B|+|2585          1130   TCTAC
# 8    positive            1606  VT6436|1|MEMB003C|-|2741          1135   TCGCG
# 9    positive            1606  VT6436|1|MEMB003D|-|2312           986   TCTAG
# 10   positive            1606  VT6436|1|MEMB003F|-|2611          1128   TCTAG
# 11   positive            1606  VT6436|1|MEMB004A|+|2422          1104   TCAAG
# 12   positive            1606  VT6436|1|MEMB004B|+|2551          1094   TCTAG
# 13   positive            1606  VT6436|1|MEMB004E|-|2496          1173   TCTAG
# 14   positive            1606  VT6436|1|MEMB005B|-|2784          1139   TCTAG
# 15   positive            1606  VT6436|1|MEMB005D|+|2691          1241   TCAAG
# 16   positive            1606  VT6436|1|MEMB006A|+|2653          1206   TCTAG
# 17   positive            1606  VT6436|1|MEMB006B|-|2624          1158   TCTAG
# 18   positive            1606  VT6436|1|MEMB006C|-|2759          1246   TCTAG
# 19   positive            1606  VT6436|1|MEMB007B|-|2711          1142   TCGCG
# 20   positive            1606  VT6436|1|MEMB007C|-|2597          1162   TCTAG
# 21   positive            1606  VT6436|1|MEMB007D|-|2947          1227   TCAAG
# 22   positive            1606  VT6436|1|MEMB008C|+|2558          1130   TCTAG
# 23   positive            1606      VT6436|1|dkik|+|2321           997   TCTAG
# 24   positive            2188  VT6436|1|MEMB002A|+|2701          1573   TCGCA
# 25   positive            2188  VT6436|1|MEMB002B|-|2408          1486   TGGCA
# 26   positive            2188  VT6436|1|MEMB002C|+|2709          1595   TCGCA
# 27   positive            2188  VT6436|1|MEMB002D|-|2501          1457   TCGCA
# 28   positive            2188  VT6436|1|MEMB002E|-|2699          1447   TCGCA
# 29   positive            2188  VT6436|1|MEMB002F|-|2670          1640   TCGCA
# ..        ...             ...                       ...           ...     ...
# 387  positive            1574  VT6436|1|MEMB006B|-|2624          1131   CAAAT
# 388  positive            1574  VT6436|1|MEMB006C|-|2759          1215   CAAAC
# 389  positive            1574  VT6436|1|MEMB007B|-|2711          1115   CAAAC
# 390  positive            1574  VT6436|1|MEMB007C|-|2597          1135   CAAAT
# 391  positive            1574  VT6436|1|MEMB007D|-|2947          1199   CAAAT
# 392  positive            1574  VT6436|1|MEMB008C|+|2558          1103   CAAAT
# 393  positive            1574      VT6436|1|dkik|+|2321           970   CAAAT
# 394  negative            2892  VT6436|1|MEMB007D|-|2947          2123   AAAGC
# 395  negative             637  VT6436|1|MEMB003C|-|2741           519   AGAGG
# 396  negative            1019  VT6436|1|MEMB002A|+|2701           830   GAAAA
# 397  negative            1019  VT6436|1|MEMB002B|-|2408           785   TCAAA
# 398  negative            1019  VT6436|1|MEMB002C|+|2709           828   TAATT
# 399  negative            1019  VT6436|1|MEMB002F|-|2670           845   AAACA
# 400  negative            1019  VT6436|1|MEMB003A|-|2262           789   CAACA
# 401  negative            1019  VT6436|1|MEMB003B|+|2585           840   CATAG
# 402  negative            1019  VT6436|1|MEMB003C|-|2741           838   TAATT
# 403  negative            1019  VT6436|1|MEMB003D|-|2312           769   CCACA
# 404  negative            1019  VT6436|1|MEMB003F|-|2611           862   CATAA
# 405  negative            1019  VT6436|1|MEMB004A|+|2422           779   TCAAA
# 406  negative            1019  VT6436|1|MEMB004B|+|2551           813   ATAAG
# 407  negative            1019  VT6436|1|MEMB004E|-|2496           843   CATAA
# 408  negative            1019  VT6436|1|MEMB005B|-|2784           845   CAAAG
# 409  negative            1019  VT6436|1|MEMB005D|+|2691           857   ATTAA
# 410  negative            1019  VT6436|1|MEMB006B|-|2624           865   CATAA
# 411  negative            1019  VT6436|1|MEMB006C|-|2759           838   CCATA
# 412  negative            1019  VT6436|1|MEMB007B|-|2711           849   TCATT
# 413  negative            1019  VT6436|1|MEMB007C|-|2597           853   CATAT
# 414  negative            1019  VT6436|1|MEMB007D|-|2947           873   ACATA
# 415  negative            1019  VT6436|1|MEMB008C|+|2558           826   CAAAA
# 416  negative            1019      VT6436|1|dkik|+|2321           774   CAACA
#
# [417 rows x 5 columns]
# /Users/niharikadesaraju/motif_extraction/data/output/VT6436_random.csv
